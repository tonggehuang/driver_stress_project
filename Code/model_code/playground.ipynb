# %%
import os
import re
import cv2
import math

import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

import datetime
import warnings
warnings.filterwarnings("ignore")

from PIL import Image

# %%
img = cv2.imread('/Users/tongge/Box/driver_stress_tong/Blackbox_images/EMP006/20170930/1506789809.jpg') 
img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)

# %%
height, width, channel = img.shape
height, width, channel
# Out:
# (960, 752, 3)

# %%
img = Image.open('/Users/tongge/Box/driver_stress_tong/Blackbox_images/EMP006/20170930/1506789809.jpg')

# %%
img = img.resize((int(img.size[0]/4),int(img.size[1]/4)),Image.ANTIALIAS)

# %%
img.size
# Out:
# (188, 240)

# %%
img
# Out:
# <PIL.Image.Image image mode=RGB size=188x240 at 0x10325BFD0>

# %%
img_roi = img[0:480, 0:752]

# %%
height, width, channel = img_roi.shape
height, width, channel

# %%
img_re = cv2.resize(img, (int(width/2),int(height/2)))

# %%
plt.imshow(img_re)

# %%
gray = cv2.cvtColor(img_re, cv2.COLOR_RGB2GRAY)

# %%
plt.imshow(gray,cmap='gray')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-5-1b6016e1e0c9> in <module>()
# ----> 1 plt.imshow(gray,cmap='gray')
#
# NameError: name 'gray' is not defined

# %%
edges = cv2.Canny(gray,150,80)

# %%
plt.imshow(edges,cmap='gray')

# %%
# HOG feature extract
from skimage.feature import hog
from skimage import data, exposure

# %%
fd_, hog_image = hog(gray, orientations=3, pixels_per_cell=(4, 4), cells_per_block=(1, 1),block_norm='L2', visualise=True)
hog_image = exposure.rescale_intensity(hog_image, in_range=(0, 10))

# %%
plt.imshow(img)
